# %%
import matplotlib
matplotlib.use('Agg')

# %%
# This is needed to display the images.4
# %matplotlib inline

# %%
import cv2
#cap = cv2.VideoCapture("rtsp://admin:admin12345@192.168.0.101/Streaming/Channels/101")
#cap = cv2.VideoCapture(0)

cap = cv2.VideoCapture("rtsp://192.168.1.140/main")

count = 0

while (cap.isOpened()):
    ret,image_np = cap.read()
    print('read a new frame:',ret)
    if count%10 == 0 :
        imS = cv2.resize(image_np, (1280, 720))
        image_np = image_np.transpose((2, 0, 1))
        image_np=image_np.transpose((1, 2, 0))
        cv2.imshow('image',image_np)
    if cv2.waitKey(25) & 0xFF == ord('q'):
        cv2.destroyAllWindows()
        cap.release()
        break
    count+=1

# %%
import cv2
#cap = cv2.VideoCapture("rtsp://admin:admin12345@192.168.0.101/Streaming/Channels/101")
#cap = cv2.VideoCapture(0)

#cap = cv2.VideoCapture("rtsp://192.168.0.139/main")
cap = cv2.VideoCapture("rtsp://admin:admin12345@192.168.1.140/Streaming/Channels/101")

#print (cap.shape())

count = 0

while (cap.isOpened()):
    ret,image_np = cap.read()
    print(image_np.shape)
    print('read a new frame:',ret)
    imS=ret
    imS = cv2.resize(image_np, (1040, 720))
    cv2.imshow('image',imS)
    
    if cv2.waitKey(25) & 0xFF == ord('q'):
        cv2.destroyAllWindows()
        cap.release()
        break
    count+=1
# Out:
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# read a new frame: True
# (720, 1280, 3)
# ...
